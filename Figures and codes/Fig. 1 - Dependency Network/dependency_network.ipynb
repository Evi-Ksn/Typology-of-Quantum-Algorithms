# %%
import pandas as pd

# %%
df = pd.read_excel("Network final.xlsx", sheet_name="Network1")[["Algorithm", "Primitive used"]]
df.head()
# Out:
#   Algorithm  Primitive used
# 0       QFT             NaN
# 1       QPE             QFT
# 2      Shor             QPE
# 3       HHL  QPE, Sparse HS
# 4       VQE             NaN

# %%
df['Primitive used'] = df['Primitive used'].apply(lambda primitive: {i for i in primitive.split(",")} if (isinstance(primitive, str) and "," in primitive) else primitive)
df
# Out:
#                                 Algorithm     Primitive used
# 0                                     QFT                NaN
# 1                                     QPE                QFT
# 2                                    Shor                QPE
# 3                                     HHL  {QPE,  Sparse HS}
# 4                                     VQE                NaN
# ..                                    ...                ...
# 129  Q. Algo. for Alchemical Optimization                VQE
# 130                     Dirac-Equation QW                NaN
# 131       QW for Non-Abelian Gauge Theory  Dirac-Equation QW
# 132   QW for Fermions in Curved Spacetime  Dirac-Equation QW
# 133                          QWs Meet LGT  Dirac-Equation QW
#
# [134 rows x 2 columns]

# %%
df_exploded = df.explode("Primitive used")
df_exploded
# Out:
#                                 Algorithm     Primitive used
# 0                                     QFT                NaN
# 1                                     QPE                QFT
# 2                                    Shor                QPE
# 3                                     HHL                QPE
# 3                                     HHL          Sparse HS
# ..                                    ...                ...
# 129  Q. Algo. for Alchemical Optimization                VQE
# 130                     Dirac-Equation QW                NaN
# 131       QW for Non-Abelian Gauge Theory  Dirac-Equation QW
# 132   QW for Fermions in Curved Spacetime  Dirac-Equation QW
# 133                          QWs Meet LGT  Dirac-Equation QW
#
# [169 rows x 2 columns]

# %%
import networkx as nx

# %%
df_exploded
# Out:
#                                 Algorithm     Primitive used
# 0                                     QFT                NaN
# 1                                     QPE                QFT
# 2                                    Shor                QPE
# 3                                     HHL                QPE
# 3                                     HHL          Sparse HS
# ..                                    ...                ...
# 129  Q. Algo. for Alchemical Optimization                VQE
# 130                     Dirac-Equation QW                NaN
# 131       QW for Non-Abelian Gauge Theory  Dirac-Equation QW
# 132   QW for Fermions in Curved Spacetime  Dirac-Equation QW
# 133                          QWs Meet LGT  Dirac-Equation QW
#
# [169 rows x 2 columns]

# %%
from networkx.drawing.nx_agraph import write_dot, graphviz_layout

# %%
# !pip install networkx --upgrade -q

# %%
# !pip install networkx --upgrade

# %%
# !pip install pyvis
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.5 MB/s eta 0:00:00
# ...

# %%
# !pip install python-louvain

# %%
from pyvis.network import Network
import community as community_louvain
import numpy as np

# %%
df_exploded['Primitive used'].replace(["ΝΑ", "NA", "nan", "NaN"], np.nan, inplace=True)


df_exploded['Primitive used'] = df_exploded['Primitive used'].astype(str).apply(str.strip)
df_exploded['Algorithm'] = df_exploded['Algorithm'].apply(str.strip)


df_exploded['Primitive used'].replace("nan", np.nan, inplace=True)


df_exploded = df_exploded.dropna(subset=['Primitive used']).reset_index(drop=True)


df_exploded
# Out:
# <ipython-input-11-7674a7444547>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_exploded['Primitive used'].replace(["ΝΑ", "NA", "nan", "NaN"], np.nan, inplace=True)
# <ipython-input-11-7674a7444547>:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# !apt-get install -qq graphviz graphviz-dev
# !pip install pygraphviz
# Out:
# Selecting previously unselected package libgtk2.0-common.
# (Reading database ... 124561 files and directories currently installed.)
# Preparing to unpack .../0-libgtk2.0-common_2.24.33-2ubuntu2.1_all.deb ...
# Unpacking libgtk2.0-common (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../1-libgtk2.0-0_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../2-libgail18_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../3-libgail-common_2.24.33-2ubuntu2.1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.33-2ubuntu2.1) ...
# Selecting previously unselected package libxdot4:amd64.
# Preparing to unpack .../4-libxdot4_2.42.2-6ubuntu0.1_amd64.deb ...
# ...

# %%
#!pip uninstall python-louvain
#!pip install python-louvain
# Out:
# Found existing installation: python-louvain 0.16
# Uninstalling python-louvain-0.16:
#   Would remove:
#     /usr/local/bin/community
#     /usr/local/lib/python3.10/dist-packages/community/*
#     /usr/local/lib/python3.10/dist-packages/python_louvain-0.16.dist-info/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.10/dist-packages/community/app.py
# Proceed (Y/n)? Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/uninstall.py", line 105, in run
#     uninstall_pathset = req.uninstall(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/req/req_install.py", line 680, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
# ...

# %%
# !pip show python-louvain
# Out:
# Name: python-louvain
# Version: 0.16
# Summary: Louvain algorithm for community detection
# Home-page: https://github.com/taynaud/python-louvain
# Author: Thomas Aynaud
# Author-email: taynaud@gmail.com
# License: BSD
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: networkx, numpy
# Required-by:

# %%
#!pip install python-louvain

# %%
#pos = nx.kamada_kawai_layout(G)

G = nx.from_pandas_edgelist(df_exploded,
                            target="Algorithm",
                            source="Primitive used",
                            create_using= nx.Graph()
                           )

# nx.draw(G)
#plt.figure(figsize=(10,10))
#pos = graphviz_layout(G, prog='dot')
pos = nx.kamada_kawai_layout(G)
import matplotlib.pyplot as plt
import community.community_louvain as community_louvain
nx.draw(G, node_color="skyblue", edge_cmap=plt.cm.Blues, pos=pos)
plt.show()

communities = community_louvain.best_partition(G)
nx.set_node_attributes(G, communities, 'group')

# %%
df_exploded.tail(30)
# Out:
#                                              Algorithm  \
# 113  Strongly Correlated Fermionic-Systems Theoreti...
# 114                        Aharonov–Jones–Landau Algo.
# 115                Q. Algo. for Feynman Loop Integrals
# 116  Q. Simulation of Effective Field Theories for ...
# 117           Q. Simulation of Deuteron Binding Energy
# 118  Continuous-Variable QITE Formulation of Scalar...
# 119  Continuous-Variable QITE Formulation of Scalar...
# 120  QITE for Feynman-Kac Partial Differential Equa...
# 121  Variational Q. Algo. for Parton Distribution F...
# 122                     Q. Algo. for Matched Filtering
# 123          Variational Q. Algo. for Poisson Equation
# 124  Q. Simulation of Hydrodynamics via Madelung Tr...
# 125   Efficient Q. Algo. for Dissipative Nonlinear DEs
# 126  Kacewicz’ Q. Ordinary-Differential-Equation Algo.
# 127                Q. Algo. for Navier–Stokes Equation
# 128                 Q. Hartree-Fock Variational Method
# ...

# %%
for row in df_exploded['Primitive used']:
    if row.strip().endswith("ΝΑ"):
        print(row)

# %%
#from pyvis.network import Network
#import networkx as nx

# %%
nx.__version__
# Out:
# '3.4.2'

# %%
net = Network(notebook=True,
              width="1400px",
              height="1000px",
              directed=True,
              cdn_resources="remote",
              font_color="black",
              bgcolor="white"
             )

net.from_nx(G)
net.show_buttons(filter_=['physics'])
# %matplotlib inline
net.show("dependency_network_final.html")
# Out:
# dependency_network_final.html
#         <iframe
#             width="1400px"
#             height="1000px"
#             src="dependency_network_final.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
